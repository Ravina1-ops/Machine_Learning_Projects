# %% [markdown]
# # Predict house price from missing data

# %% [markdown]
# import libraries

# %%
import pandas as pd 
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices_Of_multivariables.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# now fill the empty data using median because the bedroom series column is in continuous manner

# %%
import math 
import numpy as np 
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 4
