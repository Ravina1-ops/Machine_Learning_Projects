# %% [markdown]
# import libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %% [markdown]
# Read CSV or get dataset

# %%
df = pd.read_csv("canada per capita income data.csv")
df.head(5)
# Out:
#    year  per capita income(Us$)
# 0  1970             3399.299037
# 1  1971             3768.297935
# 2  1972             4251.175484
# 3  1973             4804.463248
# 4  1974             5576.514583

# %% [markdown]
# scatter the plot

# %%
# %matplotlib inline
plt.scatter(df['year'], df['per capita income(Us$)'], color = "purple", marker = "*")
plt.xlabel('year')
plt.ylabel('income per capita')
plt.title('Income Prrediction Scatter plot')
plt.show()

# %% [markdown]
# train the model using above data

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df['per capita income(Us$)'])
# Out:
# LinearRegression()

# %% [markdown]
# model is trained lets test using year 2022 prediction income

# %%
p = reg.predict(pd.DataFrame({'year': [2022]}))
p
# Out:
# array([42945.62424486])

# %% [markdown]
# how it predict value lets cross check

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %% [markdown]
#  check through equation y = m*x + b here m = coef and b = intercept

# %%
828.46507522*2022-1632210.7578554575
# Out:
# 42945.62423938257

# %% [markdown]
# fit line using regression prediction

# %%
# %matplotlib inline
plt.scatter(df['year'], df['per capita income(Us$)'], color = "purple", marker = "*")
plt.xlabel('year')
plt.ylabel('income per capita')
plt.title('Income Prrediction Scatter plot')
plt.plot(df['year'],reg.predict(df[['year']]), color = 'red')
plt.show()
